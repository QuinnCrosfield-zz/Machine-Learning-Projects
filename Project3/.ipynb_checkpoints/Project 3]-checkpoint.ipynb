# %% [markdown]
# MCS 207: Introduction to Machine Learning
# Project 3
#
# Friday, January 24th: Complete a google form telling me who you’ll work with, and what you think your
# topic will be. You are free to change your topic over the weekend, however.
#
# Monday, January 27th: Complete your project plan by the beginning of class, to be ready to discuss it.
#
# Wednesday, January 29th: Extra credit mini-presentations at the beginning of class.
#
# Thursday, January 30th and Friday, January 31st: Project presentations.
#
# Friday, January 31st: Submit project through moodle.
#
#  You may choose to work on any machine learning
# project of your choice. This could be similar to the types of regression or classification that we’ve done
# so far, or could be on machine learning related to text (things like sentiment analysis, or text generation),
# or could be on machine learning related to images (things like image recognition, or image generation), or
# another area of machine learning altogether.
# The only requirements for the project are that it should require you to go through the process of preparing
# data (in some form), some kind of exploratory data analysis, training and testing machine learning algorithms (including some parameter tuning), and evaluating the performance of your models.
# Depending on the difficulty of your project, it might not be realistic for you to complete the entire process in
# one week. For this reason, it’s very important that you give a detailed outline of the plan for your project.
# Hopefully, if you’ve chosen a project that you are unable to complete during the term, you’ll continue to
# work on it after the course is over.
# Once you’ve chosen your project, complete the following tasks.
# Write a Plan. Before you start working on your project, make a detailed plan for the workflow of your
# project. Write up this plan, and include it at the beginning of your Jupyter notebook.
# Your plan should include the following:
# • What will be your goal in working on this project?
# • What will be your source for data for the project? If this requires you to gather data, how will you go
# about this?
# • What data cleaning, conversion, or preparation will you need to do to prepare your data set?
# • What kinds of exploratory data analysis will you do?
# • Which machine learning algorithms will you use to train models? Why are you choosing these algorithms?
# • How will you attempt to optimize your models?
# • How will you analyze the accuracy of your models?
#
# It is very important that your plan is complete and very detailed, in order to show a thorough understanding
# of the process of training a model using machine learning, in case you don’t have time to fully complete your
# project. You should have a draft of your plan completed by the beginning of class on Monday,
# January 27th, so that we can discuss it.
#
# Gathering Data. Following the outline given in your plan, gather the data that you require for your
# project. Depending on your project, this might be as simple as downloading a data set, or it might involve
# combining multiple data sources, or gathering data yourself. If your project requires you to gather your own
# data, please discuss this with me before beginning, so that we can make sure you have a realistic plan to
# gather enough data.
# Preparing Your Data Set. Following the outline given in your plan, prepare your data set for training.
# This might include handling missing or categorical values, basic conversions, or more extensive conversions.
# Any choices that you make should be explained.
# Exploratory Data Analysis. Following the outline given in your plan, perform some exploratory data
# analysis. Discuss the results, and what this tells you about your data, as well as your expectations for your
# results. This should include some data visualization.
# Train Models Using Machine Learning Algorithms. Although you do not need to use every algorithm
# that we’ve covered, you should use those that make sense for your data set. You should explain your choices,
# and perform parameter tuning in order to optimize their performance.
# Discussion of Results. Compare the performance of your models, and discuss the results. Do you consider your results successful? Explain why or why not, and discuss how further improvements might be made.
# Evaluation of Your Plan. Discuss how closely you were able to follow your initial plan. What unexpected
# issues did you encounter? What adjustments did you need to make? How would this affect planning a future
# machine learning project?
# For this project, you will submit a Jupyter Notebook through moodle by Friday, January 31st, and you will
# give an in-class presentation on Thursday, January 30th or Friday, January 31st.
# Grading
# There are a maximum of 25 points possible for this project. I will post a rubric for the project early next
# week. In order to incentivize students to choose challenging projects, when grading, I will assign your
# project a difficulty multiplier for each category. This way, if your project involves very difficult data preparation, and you are only able to barely start exploratory data analysis, it still may be possible to get full credit.
#
# Project Presentations and Responses
# There are a lot of interesting project presentations happening at the end of January term: the math modeling class, physics modeling class, and board game development class will also be presenting their final
# projects. We will put together a combined schedule for presentations, and encourage our students to attend
# presentations from other classes.
# For your presentation, this means that you should anticipate that your audience will include people from
# outside of this class, who probably don’t know anything about machine learning! I encourage you to consider this when preparing your presentation, and aim to explain your project at a level that is accessible to
# a general audience.
# For your project responses, you are required to attend and respond to at least four presentations from other
# classes. You can attend and respond to additional presentations for some extra credit; I’ll give more details
# about this closer to the presentations.
# Additional Extra Credit
# At the beginning of the semester, I mentioned how it would fun to take a recipe generated with machine
# learning, try making it (without setting anything on fire), and see how it goes. If you want to try this, and
# talk about it for a couple of minutes at the beginning of class on Wednesday, January 29th, you can earn 2
# points of extra credit for the course. Hopefully you will also provide pictures.
# If you have other ideas for ways that you can experiment with using goofy results from machine learning,
# that could also work. Just let me know your idea, and we’ll talk about whether it warrants some extra
# credit.

# %% [markdown]
# # Plan
#
# Goal:
#
#
#
#
# Applying Sentiment Analysis to Musical Tagging
# - Genius API
#
#
#
# Data Sets:
#
#
# Data Collection: (Friday)
#     * Download .cvs files
#     * download packages
#     * read meta-data
#     * load data into pandas dataframe
#
# # play with features
#
#
# Preprocessing
# * fill null and ambigous values
# * converting data
#
# Exploratory Data Analysis
# * vizualize distribution (histogram, pair plots)
# * feature per feature
# * PCA decomposition
#
# Test and Train:
# * $k$-Nearest Neighbors
# * Decision Trees
# * Random Forrest
# * Support Vector Machines
#
# Optimization and Parameter Tuning
# * $k$-Nearest Neighbors: optimize k & weight
# * Decision Trees & Random Forrest: optimize max depth
# * Support Vector Machines: opt(penalty c) with linear and poly kernels
#
# Model Analysis
# * multiple cross validations splits
# * compare classifiers with accuracy
# * target accuracy  >
#     - use of the model will depend

# %%
# %matplotlib inline

import os

import IPython.display as ipd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as skl
import sklearn.utils, sklearn.preprocessing, sklearn.decomposition, sklearn.svm
import librosa
import librosa.display

import utils

plt.rcParams['figure.figsize'] = (17, 5)

# %%
# Directory where mp3 are stored.
AUDIO_DIR = os.environ.get('AUDIO_DIR')

# Load metadata and features.
tracks = utils.load('tracks.csv')
genres = utils.load('genres.csv')
features = utils.load('features.csv')
echonest = utils.load('echonest.csv')

np.testing.assert_array_equal(features.index, tracks.index)
assert echonest.index.isin(tracks.index).all()

tracks.shape, genres.shape, features.shape, echonest.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-e2602eb7e710> in <module>
#       3
#       4 # Load metadata and features.
# ----> 5 tracks = utils.load('tracks.csv')
#       6 genres = utils.load('genres.csv')
#       7 features = utils.load('features.csv')
#
# AttributeError: module 'utils' has no attribute 'load'
